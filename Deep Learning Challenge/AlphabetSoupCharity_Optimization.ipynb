# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=["EIN", "NAME"])
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df["APPLICATION_TYPE"].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
app_series = application_df["APPLICATION_TYPE"].value_counts()
app_names = app_series.index.tolist()

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = []
for i,j in zip(app_series, app_names):
  if i <= 527:
    application_types_to_replace.append(j)


# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df["CLASSIFICATION"].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df["CLASSIFICATION"].value_counts().loc[lambda x : x>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
class_series = application_df["CLASSIFICATION"].value_counts()
class_names = class_series.index.tolist()
classifications_to_replace = []
for i,j in zip(class_series, class_names):
  if i <= 1882:
    classifications_to_replace.append(j)
classifications_to_replace
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
application_df.dtypes
# Out:
# APPLICATION_TYPE          object
# AFFILIATION               object
# CLASSIFICATION            object
# USE_CASE                  object
# ORGANIZATION              object
# STATUS                     int64
# INCOME_AMT                object
# SPECIAL_CONSIDERATIONS    object
# ASK_AMT                    int64
# IS_SUCCESSFUL              int64
# dtype: object

# %%
# Convert categorical data to numeric with `pd.get_dummies`
encoded_df = pd.get_dummies(application_df, prefix=["APPLICATION_TYPE","AFFILIATION","CLASSIFICATION","USE_CASE","ORGANIZATION","INCOME_AMT",'SPECIAL_CONSIDERATIONS'])
encoded_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# 1                         0                     0                    1
# 2                         0                     0                    0
# 3                         0                     0                    1
# 4                         0                     0                    1
# ...                     ...                   ...                  ...
# 34294                     0                     0                    0
# 34295                     0                     0                    0
# 34296                     0                     0                    1
# 34297                     0                     0                    0
# 34298                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        0                    1                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    1                    0                    0  ...
# 34295                    1                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    0                    1                    0  ...
# 34298                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = encoded_df.IS_SUCCESSFUL.values
X = encoded_df.drop(columns="IS_SUCCESSFUL").values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Use Keras Tuner to find out the Optimum parametres

# %%
# Create a method that creates a new Sequential model with hyperparameter options
def create_model(hp):
    nn_model = tf.keras.models.Sequential()

    # Allow kerastuner to decide which activation function to use in hidden layers
    activation = hp.Choice('activation',['relu','tanh',"sigmoid"])
    
    # Allow kerastuner to decide number of neurons in first layer
    nn_model.add(tf.keras.layers.Dense(units=hp.Int('first_units',
        min_value=1,
        max_value=100,
        step=5), activation=activation, input_dim=2))

    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers
    for i in range(hp.Int('num_layers', 1, 6)):
        nn_model.add(tf.keras.layers.Dense(units=hp.Int('units_' + str(i),
            min_value=1,
            max_value=30,
            step=5),
            activation=activation))
    
    nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    nn_model.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])
    
    return nn_model

# %%
pip install keras-tuner --upgrade
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.3.4-py3-none-any.whl (172 kB)
#      -------------------------------------- 172.2/172.2 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<=3.20.3 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from keras-tuner) (3.20.1)
# Requirement already satisfied: packaging in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from keras-tuner) (21.3)
# Collecting kt-legacy
#   Downloading kt_legacy-1.0.4-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: tensorflow>=2.0 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from keras-tuner) (2.9.1)
# Requirement already satisfied: requests in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from keras-tuner) (2.28.1)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tensorflow>=2.0->keras-tuner) (1.6.3)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp37-cp37m-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 10.5 MB/s eta 0:00:00
# Collecting protobuf<=3.20.3
#   Downloading protobuf-3.19.6-cp37-cp37m-win_amd64.whl (896 kB)
#      -------------------------------------- 896.6/896.6 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tensorflow>=2.0->keras-tuner) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tensorflow>=2.0->keras-tuner) (2.10.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tensorflow>=2.0->keras-tuner) (4.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tensorflow>=2.0->keras-tuner) (1.14.1)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tensorflow>=2.0->keras-tuner) (0.2.0)
# Requirement already satisfied: setuptools in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tensorflow>=2.0->keras-tuner) (65.5.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tensorflow>=2.0->keras-tuner) (2.1.0)
# Collecting libclang>=13.0.0
#   Downloading libclang-16.0.0-py2.py3-none-win_amd64.whl (24.4 MB)
#      --------------------------------------- 24.4/24.4 MB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tensorflow>=2.0->keras-tuner) (1.3.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tensorflow>=2.0->keras-tuner) (2.9.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tensorflow>=2.0->keras-tuner) (2.9.0)
# Collecting flatbuffers<2,>=1.12
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy>=1.20 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tensorflow>=2.0->keras-tuner) (1.21.5)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tensorflow>=2.0->keras-tuner) (1.1.2)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tensorflow>=2.0->keras-tuner) (2.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tensorflow>=2.0->keras-tuner) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tensorflow>=2.0->keras-tuner) (1.42.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from packaging->keras-tuner) (3.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from requests->keras-tuner) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from requests->keras-tuner) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from requests->keras-tuner) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from requests->keras-tuner) (1.26.12)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from astunparse>=1.6.0->tensorflow>=2.0->keras-tuner) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0->keras-tuner) (2.6.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0->keras-tuner) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0->keras-tuner) (0.4.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0->keras-tuner) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0->keras-tuner) (0.6.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.0->keras-tuner) (2.0.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.0->keras-tuner) (4.7.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.0->keras-tuner) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.0->keras-tuner) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.0->keras-tuner) (1.3.1)
# Requirement already satisfied: importlib-metadata in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow>=2.0->keras-tuner) (4.11.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.0->keras-tuner) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.0->keras-tuner) (3.2.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from importlib-metadata->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow>=2.0->keras-tuner) (3.8.0)
# Installing collected packages: libclang, kt-legacy, flatbuffers, tensorflow-io-gcs-filesystem, protobuf, gast, keras-tuner
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.1
#     Uninstalling protobuf-3.20.1:
#       Successfully uninstalled protobuf-3.20.1
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
# Successfully installed flatbuffers-1.12 gast-0.4.0 keras-tuner-1.3.4 kt-legacy-1.0.4 libclang-16.0.0 protobuf-3.19.6 tensorflow-io-gcs-filesystem-0.31.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import the kerastuner library
import keras_tuner as kt

tuner = kt.Hyperband(
    create_model,
    objective="val_accuracy",
    max_epochs=20,
    hyperband_iterations=2)

# %%
# Run the kerastuner search for best hyperparameters
tuner.search(X_train_scaled,y_train,epochs=20,validation_data=(X_test_scaled,y_test))
# Out:
# Search: Running Trial #4
#
# Value             |Best Value So Far |Hyperparameter
# tanh              |tanh              |activation
# 56                |1                 |first_units
# 5                 |3                 |num_layers
# 11                |26                |units_0
# 21                |1                 |units_1
# 21                |1                 |units_2
# 1                 |None              |units_3
# 3                 |3                 |tuner/epochs
# 0                 |0                 |tuner/initial_epoch
# 2                 |2                 |tuner/bracket
# 0                 |0                 |tuner/round
#
# Epoch 1/3
# Traceback (most recent call last):
#   File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras_tuner\engine\base_tuner.py", line 270, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras_tuner\engine\base_tuner.py", line 235, in _run_and_update_trial
#     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#   File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras_tuner\tuners\hyperband.py", line 425, in run_trial
#     return super().run_trial(trial, *fit_args, **fit_kwargs)
#   File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras_tuner\engine\tuner.py", line 287, in run_trial
#     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#   File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras_tuner\engine\tuner.py", line 214, in _build_and_fit_model
#     results = self.hypermodel.fit(hp, model, *args, **kwargs)
#   File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras_tuner\engine\hypermodel.py", line 144, in fit
#     return model.fit(*args, **kwargs)
#   File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "C:\Users\david\AppData\Local\Temp\__autograph_generated_file2hs1arh5.py", line 15, in tf__train_function
#     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
# ValueError: in user code:
#
#     File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras\engine\training.py", line 1051, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras\engine\training.py", line 1040, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras\engine\training.py", line 1030, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras\engine\training.py", line 889, in train_step
#         y_pred = self(x, training=True)
#     File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras\engine\input_spec.py", line 264, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential" is incompatible with the layer: expected shape=(None, 2), found shape=(None, 43)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32836\1874305172.py in <module>
#       1 # Run the kerastuner search for best hyperparameters
# ----> 2 tuner.search(X_train_scaled,y_train,epochs=20,validation_data=(X_test_scaled,y_test))
#
# ~\anaconda3\envs\pythondata\lib\site-packages\keras_tuner\engine\base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     229             self.on_trial_begin(trial)
#     230             self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
# --> 231             self.on_trial_end(trial)
#     232         self.on_search_end()
#     233
#
# ~\anaconda3\envs\pythondata\lib\site-packages\keras_tuner\engine\base_tuner.py in on_trial_end(self, trial)
#     333             trial: A `Trial` instance.
#     334         """
# --> 335         self.oracle.end_trial(trial)
#     336         # Display needs the updated trial scored by the Oracle.
#     337         self._display.on_trial_end(self.oracle.get_trial(trial.trial_id))
#
# ~\anaconda3\envs\pythondata\lib\site-packages\keras_tuner\engine\oracle.py in wrapped_func(*args, **kwargs)
#     105             LOCKS[oracle].acquire()
#     106             THREADS[oracle] = thread_name
# --> 107         ret_val = func(*args, **kwargs)
#     108         if need_acquire:
#     109             THREADS[oracle] = None
#
# ~\anaconda3\envs\pythondata\lib\site-packages\keras_tuner\engine\oracle.py in end_trial(self, trial)
#     432         if not self._retry(trial):
#     433             self.end_order.append(trial.trial_id)
# --> 434             self._check_consecutive_failures()
#     435
#     436         self._save_trial(trial)
#
# ~\anaconda3\envs\pythondata\lib\site-packages\keras_tuner\engine\oracle.py in _check_consecutive_failures(self)
#     387                     "Number of consecutive failures excceeded the limit "
#     388                     f"of {self.max_consecutive_failed_trials}.\n"
# --> 389                     + trial.message
#     390                 )
#     391
#
# RuntimeError: Number of consecutive failures excceeded the limit of 3.
# Traceback (most recent call last):
#   File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras_tuner\engine\base_tuner.py", line 270, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras_tuner\engine\base_tuner.py", line 235, in _run_and_update_trial
#     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#   File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras_tuner\tuners\hyperband.py", line 425, in run_trial
#     return super().run_trial(trial, *fit_args, **fit_kwargs)
#   File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras_tuner\engine\tuner.py", line 287, in run_trial
#     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#   File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras_tuner\engine\tuner.py", line 214, in _build_and_fit_model
#     results = self.hypermodel.fit(hp, model, *args, **kwargs)
#   File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras_tuner\engine\hypermodel.py", line 144, in fit
#     return model.fit(*args, **kwargs)
#   File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "C:\Users\david\AppData\Local\Temp\__autograph_generated_file2hs1arh5.py", line 15, in tf__train_function
#     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
# ValueError: in user code:
#
#     File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras\engine\training.py", line 1051, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras\engine\training.py", line 1040, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras\engine\training.py", line 1030, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras\engine\training.py", line 889, in train_step
#         y_pred = self(x, training=True)
#     File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\david\anaconda3\envs\pythondata\lib\site-packages\keras\engine\input_spec.py", line 264, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" is '
#
#     ValueError: Input 0 of layer "sequential" is incompatible with the layer: expected shape=(None, 2), found shape=(None, 43)

# %%
# Get top 3 model hyperparameters and print the values
top_hyper = tuner.get_best_hyperparameters()
for param in top_hyper:
    print(param.values)
# Out:
# {'activation': 'tanh', 'first_units': 1, 'num_layers': 3, 'units_0': 26, 'tuner/epochs': 3, 'tuner/initial_epoch': 0, 'tuner/bracket': 2, 'tuner/round': 0, 'units_1': 1, 'units_2': 1}

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 5,981
# Trainable params: 5,981
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
logdir = os.path.join("log", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5705 - accuracy: 0.7208
# Epoch 2/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5563 - accuracy: 0.7280
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5531 - accuracy: 0.7301
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5509 - accuracy: 0.7318
# Epoch 5/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5495 - accuracy: 0.7315
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5486 - accuracy: 0.7317
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5479 - accuracy: 0.7322
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5466 - accuracy: 0.7332
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5464 - accuracy: 0.7325
# Epoch 10/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5462 - accuracy: 0.7325
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5457 - accuracy: 0.7336
# Epoch 12/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5451 - accuracy: 0.7337
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5442 - accuracy: 0.7338
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5447 - accuracy: 0.7345
# Epoch 15/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5433 - accuracy: 0.7353
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5432 - accuracy: 0.7338
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5427 - accuracy: 0.7345
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5430 - accuracy: 0.7352
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5424 - accuracy: 0.7351
# Epoch 20/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5420 - accuracy: 0.7357
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5421 - accuracy: 0.7351
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5421 - accuracy: 0.7363
# Epoch 23/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5416 - accuracy: 0.7354
# Epoch 24/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5410 - accuracy: 0.7365
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5410 - accuracy: 0.7362
# Epoch 26/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5410 - accuracy: 0.7356
# Epoch 27/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5407 - accuracy: 0.7370
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5410 - accuracy: 0.7364
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5402 - accuracy: 0.7371
# Epoch 30/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5402 - accuracy: 0.7360
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5402 - accuracy: 0.7373
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5398 - accuracy: 0.7372
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5399 - accuracy: 0.7374
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5394 - accuracy: 0.7374
# Epoch 35/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5393 - accuracy: 0.7371
# Epoch 36/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5393 - accuracy: 0.7371
# Epoch 37/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5388 - accuracy: 0.7375
# Epoch 38/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5390 - accuracy: 0.7379
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.7374
# Epoch 40/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5387 - accuracy: 0.7371
# Epoch 41/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5384 - accuracy: 0.7383
# Epoch 42/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5384 - accuracy: 0.7386
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.7381
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7388
# Epoch 45/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5379 - accuracy: 0.7387
# Epoch 46/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7383
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5378 - accuracy: 0.7395
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5376 - accuracy: 0.7393
# Epoch 49/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5377 - accuracy: 0.7378
# Epoch 50/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5377 - accuracy: 0.7388
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5376 - accuracy: 0.7392
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5369 - accuracy: 0.7383
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5373 - accuracy: 0.7379
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5364 - accuracy: 0.7388
# Epoch 55/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5372 - accuracy: 0.7387
# Epoch 56/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5367 - accuracy: 0.7390
# Epoch 57/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5367 - accuracy: 0.7386
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5365 - accuracy: 0.7390
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5368 - accuracy: 0.7401
# Epoch 60/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5366 - accuracy: 0.7392
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7392
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5370 - accuracy: 0.7393
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5361 - accuracy: 0.7390
# Epoch 64/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5367 - accuracy: 0.7388
# Epoch 65/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5365 - accuracy: 0.7390
# Epoch 66/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5362 - accuracy: 0.7385
# Epoch 67/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5362 - accuracy: 0.7384
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5364 - accuracy: 0.7390
# Epoch 69/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5361 - accuracy: 0.7399
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5358 - accuracy: 0.7399
# Epoch 71/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5356 - accuracy: 0.7397
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7398
# Epoch 73/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7395
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5358 - accuracy: 0.7395
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5357 - accuracy: 0.7390
# Epoch 76/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7388
# Epoch 77/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5353 - accuracy: 0.7391
# Epoch 78/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5355 - accuracy: 0.7384
# Epoch 79/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5356 - accuracy: 0.7381
# Epoch 80/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7389
# Epoch 81/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5352 - accuracy: 0.7390
# Epoch 82/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5353 - accuracy: 0.7395
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5348 - accuracy: 0.7399
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7398
# Epoch 85/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5355 - accuracy: 0.7393
# Epoch 86/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5350 - accuracy: 0.7395
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5351 - accuracy: 0.7386
# Epoch 88/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5355 - accuracy: 0.7388
# Epoch 89/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5351 - accuracy: 0.7388
# Epoch 90/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5349 - accuracy: 0.7394
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7392
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5351 - accuracy: 0.7398
# Epoch 93/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5345 - accuracy: 0.7395
# Epoch 94/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5347 - accuracy: 0.7397
# Epoch 95/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5352 - accuracy: 0.7385
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5348 - accuracy: 0.7396
# Epoch 97/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5345 - accuracy: 0.7395
# Epoch 98/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5345 - accuracy: 0.7400
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7393
# Epoch 100/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5345 - accuracy: 0.7405

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5660 - accuracy: 0.7289 - 770ms/epoch - 3ms/step
# Loss: 0.5659924745559692, Accuracy: 0.728863000869751

# %%
# Export our model to HDF5 file
# save the model to an H5 file
nn.save('AlphabetSoupCharity.h5')

# load the saved model from the H5 file
# loaded_model = tf.keras.models.load_model('my_model.h5')

# %%
from google.colab import files
files.download("AlphabetSoupCharity.h5")
